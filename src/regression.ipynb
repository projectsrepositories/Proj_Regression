# %%
import regression
# Out:
# Mean Squared Error (MSE), Mean Abs Error(MAE), R-Squared (R-2) and Pearson's Correlation Coef (PCC) of
# 1. Simple Linear Regression for the first variable (SLR_var1),
# 2. Simple Linear Regression for the second variable (SLR_var2), and
# 3. Multiple Linear Regression (MLR)
# Average model performance:
#            MSE_Avg10  MAE_Avg10  R-Squared_Avg10  PCC_Avg10
# SLR_Var1  963.483669  23.351852         0.765962   0.877122
# SLR_Var2  829.069496  20.513820         0.797480   0.894948
# MLR       565.440367  17.172404         0.862313   0.929904
